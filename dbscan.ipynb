# %% [markdown]
# # DBSCAN Clustering

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons

# %%
x,y=make_moons(n_samples=250,noise=0.05)

# %%
df={"data1":x[:,0],"data2":x[:,1],"output":y}

# %%
dataset=pd.DataFrame(df)

# %%
dataset.head()
# Out:
#       data1     data2  output
# 0 -0.077364  1.027571       0
# 1  0.782594  0.626012       0
# 2  0.007710  0.146594       1
# 3  1.684175 -0.276343       1
# 4  1.929509  0.154068       1

# %%
new_dataset=dataset.iloc[:,:-1]

# %%
from sklearn.cluster import DBSCAN

# %%
db=DBSCAN(eps=0.2,min_samples=5)

# %%
new_dataset["predict"]= db.fit_predict(new_dataset)

# %%
new_dataset
# Out:
#         data1     data2  predict
# 0   -0.077364  1.027571        0
# 1    0.782594  0.626012        0
# 2    0.007710  0.146594        1
# 3    1.684175 -0.276343        1
# 4    1.929509  0.154068        1
# ..        ...       ...      ...
# 245  0.243569  1.040737        0
# 246  0.474613  0.838540        0
# 247  0.982813 -0.033236        0
# 248  1.993579  0.252352        1
# 249  1.886357  0.206667        1
#
# [250 rows x 3 columns]

# %%
sns.scatterplot(x="data1",y="data2",hue="predict",data=new_dataset)
plt.show()
